# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'Data\2-chase_CA_2023_HMDA.csv')
# Out:
# C:\Users\samvi\AppData\Local\Temp\ipykernel_22652\2313695487.py:1: DtypeWarning: Columns (43,46,77,78,79,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'Data\2-chase_CA_2023_HMDA.csv')

# %%
df.columns
# Out:
# Index(['activity_year', 'lei', 'derived_msa-md', 'state_code', 'county_code',
#        'census_tract', 'conforming_loan_limit', 'derived_loan_product_type',
#        'derived_dwelling_category', 'derived_ethnicity', 'derived_race',
#        'derived_sex', 'action_taken', 'purchaser_type', 'preapproval',
#        'loan_type', 'loan_purpose', 'lien_status', 'reverse_mortgage',
#        'open-end_line_of_credit', 'business_or_commercial_purpose',
#        'loan_amount', 'loan_to_value_ratio', 'interest_rate', 'rate_spread',
#        'hoepa_status', 'total_loan_costs', 'total_points_and_fees',
#        'origination_charges', 'discount_points', 'lender_credits', 'loan_term',
#        'prepayment_penalty_term', 'intro_rate_period', 'negative_amortization',
#        'interest_only_payment', 'balloon_payment',
#        'other_nonamortizing_features', 'property_value', 'construction_method',
#        'occupancy_type', 'manufactured_home_secured_property_type',
# ...

# %%
df.head()
# Out:
#    activity_year                   lei  derived_msa-md state_code  \
# 0           2023  7H6GLXDRUGQFU57RNE97           36084         CA
# 1           2023  7H6GLXDRUGQFU57RNE97           41940         CA
# 2           2023  7H6GLXDRUGQFU57RNE97           31084         CA
# 3           2023  7H6GLXDRUGQFU57RNE97           40900         CA
# 4           2023  7H6GLXDRUGQFU57RNE97           40140         CA
#
#    county_code  census_tract conforming_loan_limit derived_loan_product_type  \
# 0         6001    6001400600                     C   Conventional:First Lien
# 1         6085    6085505303                     C   Conventional:First Lien
# 2         6037    6037554301                     C   Conventional:First Lien
# 3         6067    6067004909                     C   Conventional:First Lien
# 4         6065    6065042521                     C   Conventional:First Lien
#
#               derived_dwelling_category        derived_ethnicity  \
# ...

# %%
#cols = ['loan_to_value_ratio', 'loan_amount']

#df2 = df[cols]

x = df['rate_spread']
y = df['loan_to_value_ratio']

plt.scatter(x, y)
plt.xlabel('rate_spread')
plt.ylabel('loan_to_value_ratio')
plt.title('rate_spread VS loan_to_value_ratio')
plt.show()

# %%
def simp_hist(df, col):
    df[col].plot.hist(bins=20, edgecolor='black')

    plt.title(str(col) + ' Distribution')
    plt.xlabel(str(col))
    plt.ylabel('Frequency')
    plt.show()

# %%
max(df['property_value'])
# Out:
# 340005000.0

# %%
top_values = df['property_value'].nlargest(5).iloc[1:]  # top 8, drop max
top_values.hist()
plt.show()

# %%
simp_hist(df, 'activity_year')

# %%
df[(df['lei'] == '7H6GLXDRUGQFU57RNE97') & ]
# Out:
#        activity_year                   lei  derived_msa-md state_code  \
# 0               2023  7H6GLXDRUGQFU57RNE97           36084         CA
# 1               2023  7H6GLXDRUGQFU57RNE97           41940         CA
# 2               2023  7H6GLXDRUGQFU57RNE97           31084         CA
# 3               2023  7H6GLXDRUGQFU57RNE97           40900         CA
# 4               2023  7H6GLXDRUGQFU57RNE97           40140         CA
# ...              ...                   ...             ...        ...
# 88912           2023  7H6GLXDRUGQFU57RNE97           42034         CA
# 88913           2023  7H6GLXDRUGQFU57RNE97           31084         CA
# 88914           2023  7H6GLXDRUGQFU57RNE97           40900         CA
# 88915           2023  7H6GLXDRUGQFU57RNE97           42220         CA
# 88916           2023  7H6GLXDRUGQFU57RNE97           42220         CA
#
#        county_code  census_tract conforming_loan_limit  \
# 0             6001    6001400600                     C
# ...

# %%
filtered_df = df[
    pd.to_numeric(df['intro_rate_period'], errors='coerce').astype('Int64') !=
    pd.to_numeric(df['loan_term'], errors='coerce').astype('Int64')
]
pd.set_option('display.max_columns', None)
filtered_df
# Out:
#        activity_year                   lei  derived_msa-md state_code  \
# 26              2023  7H6GLXDRUGQFU57RNE97           40900         CA
# 30              2023  7H6GLXDRUGQFU57RNE97           31084         CA
# 31              2023  7H6GLXDRUGQFU57RNE97           11244         CA
# 38              2023  7H6GLXDRUGQFU57RNE97           31084         CA
# 39              2023  7H6GLXDRUGQFU57RNE97           41940         CA
# ...              ...                   ...             ...        ...
# 88892           2023  7H6GLXDRUGQFU57RNE97           40900         CA
# 88896           2023  7H6GLXDRUGQFU57RNE97           42034         CA
# 88904           2023  7H6GLXDRUGQFU57RNE97           41740         CA
# 88906           2023  7H6GLXDRUGQFU57RNE97           36084         CA
# 88911           2023  7H6GLXDRUGQFU57RNE97           36084         CA
#
#        county_code  census_tract conforming_loan_limit  \
# 26            6067    6067005606                    NC
# ...

# %%
df['intro_rate_period'].value_counts()
# Out:
# intro_rate_period
# 1.0      15124
# 84.0     14348
# 120.0    13096
# 62.0      2760
# 360.0     2333
# 60.0      1876
# 300.0      385
# 36.0       318
# 180.0       91
# 6.0         66
# 12.0        26
# 3.0         13
# 25.0         8
# 7.0          4
# 24.0         3
# 240.0        2
# 37.0         2
# 54.0         1
# 61.0         1
# 31.0         1
# 30.0         1
# 16.0         1
# 32.0         1
# 19.0         1
# 18.0         1
# 44.0         1
# 13.0         1
# Name: count, dtype: int64

# %%
cols_to_keep = ['lien_status', 'loan_to_value_ratio', 'interest_only_payment', 'intro_rate_period',
                'balloon_payment', 'negative_amortization', 'loan_amount', 'loan_term', 'action_taken', 
                'loan_purpose', 'interest_rate', 'rate_spread']

df = df[cols_to_keep]

# %%
df.head()
# Out:
#    lien_status  loan_to_value_ratio  interest_only_payment  intro_rate_period  \
# 0            1                  NaN                      2                NaN
# 1            1                  NaN                      2                NaN
# 2            1                  NaN                      2                NaN
# 3            1                  NaN                      2                NaN
# 4            1                  NaN                      2                NaN
#
#    balloon_payment  negative_amortization  loan_amount  loan_term  \
# 0                2                      2     305000.0      360.0
# 1                2                      2     405000.0      360.0
# 2                2                      2     525000.0      360.0
# 3                2                      2     265000.0      360.0
# 4                2                      2     295000.0      360.0
#
#    action_taken  loan_purpose  interest_rate  rate_spread
# ...
