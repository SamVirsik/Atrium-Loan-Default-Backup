# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\samvi\Documents\Coding Projects\Embedded Work\Data_Used\Fannie, Severely Adverse.csv')

# %%
df.head()
# Out:
#          Date  Real GDP growth  Nominal GDP growth  \
# 0  2001-01-01             -1.1                 1.4
# 1  2001-04-01              2.1                 5.1
# 2  2001-07-01             -1.3                 0.0
# 3  2001-10-01              1.1                 2.3
# 4  2002-01-01              3.7                 5.1
#
#    Real disposable income growth  Nominal disposable income growth  \
# 0                            3.5                               6.3
# 1                           -0.3                               1.6
# 2                            9.8                              10.1
# 3                           -4.9                              -4.6
# 4                           10.1                              10.9
#
#    Unemployment rate  CPI inflation rate  3-month Treasury yield  \
# 0                4.2                 3.9                     4.8
# 1                4.4                 2.8                     3.7
# ...

# %%
def convert_quarter_to_date(qtr_str):
    quarter, year = qtr_str.split()
    month = {'Q1': 1, 'Q2': 4, 'Q3': 7, 'Q4': 10}[quarter]
    return pd.Timestamp(year=int(year), month=month, day=1)

# Apply the function to create a new datetime column
df['Date'] = df['Date'].apply(convert_quarter_to_date)

# %%
df.head()
# Out:
#         Date  Real GDP growth  Nominal GDP growth  \
# 0 2001-01-01             -1.1                 1.4
# 1 2001-04-01              2.1                 5.1
# 2 2001-07-01             -1.3                 0.0
# 3 2001-10-01              1.1                 2.3
# 4 2002-01-01              3.7                 5.1
#
#    Real disposable income growth  Nominal disposable income growth  \
# 0                            3.5                               6.3
# 1                           -0.3                               1.6
# 2                            9.8                              10.1
# 3                           -4.9                              -4.6
# 4                           10.1                              10.9
#
#    Unemployment rate  CPI inflation rate  3-month Treasury yield  \
# 0                4.2                 3.9                     4.8
# 1                4.4                 2.8                     3.7
# ...

# %%
df.to_csv(r'C:\Users\samvi\Documents\Coding Projects\Embedded Work\Data_Used\Fannie, Severely Adverse.csv', index=False)
